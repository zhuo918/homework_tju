# %%
with open("requirements.txt", mode="w") as file:
    for module in "flask", "sklearn", "numpy", "matplotlib":
        pymodule = __import__(module)
        file.write(f"{module}=={pymodule.__version__}\n")
